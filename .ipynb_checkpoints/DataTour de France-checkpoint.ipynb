# %% [markdown]
# # DataTour de France

# %% [markdown]
# In this notebook, we'll look at the many steps it takes to go from gathering unstructured data, to cleaning and analyzing it. We'll start by collecting data by means of web scraping. We'll clean up a little bit our dataset manually. Finally, we'll explore some aspects of the way the Tour de France changed during one century.

# %% [markdown]
# ## Collecting global data

# %% [markdown]
# As a first step, we will collect general data about the Tour de France. We'll store this data in a pandas DataFrame so we can use well formated data later on for our analysis.
#
# In that purpose, we will scrape data from several websites and aggregate it into a single DataFrame. We will use **BeautifulSoup** which is a Python module used to parse HTML and XML files.

# %%
from bs4 import BeautifulSoup
import re
import math
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
r = requests.get("http://bikeraceinfo.com/tdf/tdfindex.html")
soup = BeautifulSoup(r.text, "lxml")
table = soup.find("table")

# %% [markdown]
# Let's build a dictionary we will use later to feed our DataFrame.

# %%
metadata = {"year": [], "winner": [], "second": [], "third": [], "winner_origin": [], "winning_team": []}

# %% [markdown]
# ### Retrieve each year the Tour de France took place

# %% [markdown]
# [This web page](http://bikeraceinfo.com/tdf/tdfindex.html) stores every general information about each year the Tour de France took place. We'll scrape it step by step to retrive all the data it stores.

# %%
regex = re.compile(r"[0-9]{4}$")

for sib in table.tr.next_siblings:
    try:
        y = sib.td.text
        if re.match(regex, sib.td.text) != None:
            metadata["year"].append(y)
        else:
            # We want to get rid off the years that the Tour de France did not take place
            print(sib.td.text)
    except AttributeError:
        pass
# Out:
# 1915-1918 World War I, no Tours held
# 1940-1946 World War II, no Tours held
# 2020V

# %% [markdown]
# ### Retrieve every winner of the Tour de France

# %% [markdown]
# Next, we want to move to the next column and retrieve each winner. The cell stores additional data that we need to clean a little bit further if we want to use it for some further analysis.

# %%
def remove_backspace(text):
    regex = re.compile(r"[\n\t]")
    text = regex.sub("", text)
    return text

# %%
for sib in table.tr.next_siblings:
    try:
        t = sib.td.next_sibling.next_sibling.get_text()
        metadata["winner"].append(remove_backspace(t))
    except AttributeError:
        pass

# %%
# Let's remove a non-necessary line
del metadata["winner"][-2]

# %% [markdown]
# ### Retrieve each participant that achieved the second place

# %%
for sib in table.tr.next_siblings:
    try:
        t = sib.find_all("td")
        # Because the table does not have the same number of cells when the Tour did not take place
        try:
            sec = t[3].get_text(strip=True)
            metadata["second"].append(sec)
        except IndexError:
            pass
    except AttributeError:
        pass

# %%
# Let's remove a non-necessary line
del metadata["second"][-2]

# %% [markdown]
# ### Retrieve each participant that achieved the third place

# %%
for sib in table.tr.next_siblings:
    try:
        t = sib.find_all("td")
        # Because the table does not have the same number of cells when the Tour did not take place
        try:
            thd = t[4].get_text(strip=True)
            metadata["third"].append(thd)
        except IndexError:
            pass
    except AttributeError:
        pass

# %%
# Let's remove a non-necessary line
del metadata["third"][-2]

# %% [markdown]
# ### Retrieve each winning team (It is the team to which the yellow jersey belongs to)

# %%
for i, sib in enumerate(table.tr.next_siblings):
    try:
        t = sib.find_all("td")
        # Because the table does not have the same number of cells when the Tour did not take place
        try:
            team = t[2].get_text(strip=True)
            if "," in team:
                te = team.split(",")
                metadata["winner_origin"].append(te[0])
                metadata["winning_team"].append(te[1])
            else:
                print(math.ceil(i/2-3), team)
        except IndexError:
            pass
    except AttributeError:
        pass
# Out:
# 90 USAUS Postal
# 91 USADiscovery
# 92 SpainCaissed'Epargne
# 93 SpainDiscovery
# 94 SpainCSC-Saxo Bank
# 95 SpainAstana
# 96 LuxembourgSaxo Bank
# 97 AustraliaBMC
# 98 Great BritainSky
# 99 Great BritainSky
# 100 ItalyAstana
# 101 Great BritainSky
# 102 Great BritainSky
# 103 Great BritainSky
# 104 Great BritainSky
# 105 ColombiaINEOS
# 106
# 107 SloveniaUAE-Team Emirates

# %% [markdown]
# Because the rest of the dataset is not really well formated, let's add the final data manually.

# %%
metadata["winner_origin"].append("USA")
metadata["winning_team"].append("US Postal")

# %%
metadata["winner_origin"].append("USA")
metadata["winning_team"].append("Discovery")

# %%
metadata["winner_origin"].append("Spain")
metadata["winning_team"].append("Caisse d'Epargne")

# %%
metadata["winner_origin"].append("Spain")
metadata["winning_team"].append("Discovery")

# %%
metadata["winner_origin"].append("Spain")
metadata["winning_team"].append("CSC-Saxo Bank")

# %%
metadata["winner_origin"].append("Spain")
metadata["winning_team"].append("Astana")

# %%
metadata["winner_origin"].append("Luxembourg")
metadata["winning_team"].append("Saxo Bank")

# %%
metadata["winner_origin"].append("Australia")
metadata["winning_team"].append("BMC")

# %%
for i in range(98, 105):
    metadata["winner_origin"].append("Great Britain")
    metadata["winning_team"].append("Sky")

# %%
metadata["winner_origin"].append("Columbia")
metadata["winning_team"].append("INEOS")

# %%
metadata["winner_origin"].append("Slovenia")
metadata["winning_team"].append("UAE-Team Emirates")

# %%
for key, val in metadata.items():
    print(len(metadata[key]))
# Out:
# 107
# 107
# 107
# 107
# 107
# 107

# %%
df = pd.DataFrame(metadata)

# %% [markdown]
# ## Let's add some new fields in our metadata dictionary

# %% [markdown]
# Before we move on, we want to add some new fields in our `metadata` dictionary. We will use them later to feed our DataFrame with new data sources

# %%
metadata["winner_chrono"] = []
metadata["winner_timedelta"] = []

# %% [markdown]
# ### Let's clean up a little bit some columns

# %% [markdown]
# #### Retrieve age of winners

# %% [markdown]
# Our "winner" column contains more information but it is kind of messy. Let's try to clean it a little bit more. First, we'll start by retrieving the age of the winner. We'll use a simple regular expression for that : by scanning through the dataset, there is only one suspicious data, being 14 years old. This seems kind of young to win the Tour de France. By inspecting it closer, it looks like there is some missing data for that year. We'll replace it manually.

# %%
def get_age(text):
    regex = re.compile(r"\d{2}")
    find = re.search(regex, text)
    return find.group()

# %%
list_age = []

for i, win in enumerate(df["winner"]):
    age = get_age(win)
    list_age.append(age)
    print(i, age, df["winner"][i])
# Out:
# 0 32 Garin, Maurice, 3293hr 33min 14sec
# 1 20 Cornet, Henri, 2096hr 5min 55sec
# 2 24 Trousselier, Louis, 2435 points
# 3 27 Pottier, René, 2731 points
# 4 24 Petit-Breton, Lucien, 2447 points
# 5 25 Petit-Breton, Lucien, 2536 points
# 6 22 Faber, François, 2237 points
# 7 22 Lapize, Octave, 2263 points
# 8 29 Garrigou, Gustave, 2943 points
# 9 24 Defraye, Odile, 2449 points
# 10 23 Thys, Philippe, 23197hr 54min 0sec
# 11 24 Thys, Philippe, 24200hr 28min 49sec
# 12 33 Lambot, Firmin, 33231hr 7min 15sec
# 13 30 Thys, Philippe, 30228hr 36min 13sec
# 14 33 Scieur, Léon 33221hr 36min 0sec
# 15 36 Lambot, Firmin, 36222hr 8min 6sec
# 16 34 Pélissier, Henri, 34222hr 15min 30sec
# 17 30 Bottecchia, Ottavio, 30226hr 18min 21sec
# 18 31 Bottecchia, Ottavio, 31219hr 10min 18sec
# 19 33 Buysse, Lucien, 33238hr 44min 25sec
# 20 28 Frantz, Nicolas, 28198hr 16min 42sec
# 21 29 Frantz, Nicolas, 29192hr 48min 58sec
# 22 33 De Waele, Maurice, 33186hr 39min 16sec
# ...

# %%
# Let's modify manually the missing value
list_age[31] = 24

# %%
# Finally, let's add the data to our DataFrame
df["age"] = list_age

# %% [markdown]
# #### Retrieve winners' chrono

# %% [markdown]
# The winner's column contains information about their total chrono : how much time did it take them to go from the first stage to the last. We want to store that information in a dedicated column, that might be helpful later on if we want to calculate the performance of each winner.

# %%
def get_chrono(text):
    regex = re.compile(r"(?<=\d{2}).+")
    find = re.search(regex, text)
    return find.group()

# %%
df.iloc[21]["winner"].replace("\xa0", " ")
# Out:
# 'Frantz, Nicolas, 29192hr 48min 58sec '

# %%
for i, win in enumerate(df["winner"]):
    chrono = get_chrono(win)
    # Replace non-breaking spaces
    chrono = chrono.replace("\xa0", " ")
    # Handling one badly formated cell
    chrono = chrono.replace("; ", "")
    try:
        delta = pd.to_timedelta(chrono)
        metadata["winner_chrono"].append(chrono)
        metadata["winner_timedelta"].append(delta)
    except ValueError:
        metadata["winner_chrono"].append(np.nan)
        metadata["winner_timedelta"].append(np.nan)

# %% [markdown]
# Because some of the data that represents the winner's time are not properly formated or even sometimes wrong, we will correct those piece of data manually.

# %%
df["winner_chrono"] = metadata["winner_chrono"]
df["winner_timedelta"] = metadata["winner_timedelta"]

# %%
df.at[0, "winner_chrono"] = "94hr 33min 14sec"
df.at[0, "winner_timedelta"] = pd.to_timedelta("94hr 33min 14sec")

# %%
df.at[92, "winner_chrono"] = "89hr 39min 30sec"
df.at[92, "winner_timedelta"] = pd.to_timedelta("89hr 39min 30sec")

# %%
df.at[96, "winner_chrono"] = "91hr 58min 48sec"
df.at[96, "winner_timedelta"] = pd.to_timedelta("91hr 58min 48sec")

# %%
df[df["winner_chrono"].isnull()]
# Out:
#    year                             winner                       second  \
# 2  1905    Trousselier, Louis, 2435 points  HippolyteAucouturier61 pts.
# 3  1906         Pottier, René, 2731 points      Georges Passerieu39 pts
# 4  1907  Petit-Breton, Lucien, 2447 points       Gustave Garrigou66 pts
# 5  1908  Petit-Breton, Lucien, 2536 points         François Faber68 pts
# 6  1909       Faber, François, 2237 points       Gustave Garrigou57 pts
# 7  1910        Lapize, Octave, 2263 points         François Faber67 pts
# 8  1911     Garrigou, Gustave, 2943 points             Paul Duboc61 pts
# 9  1912        Defraye, Odile, 2449 points     Eugène Christophe108 pts
#
#                             third winner_origin winning_team age  \
# 2  Jean-BaptisteDortignacq64 pts.        France      Peugeot  24
# 3           LouisTrousselier59pts        France      Peugeot  27
# 4             Émile Georget74 pts        France      Peugeot  24
# ...

# %%
df.iloc[76]
# Out:
# year                                            1990
# winner              LeMond, Greg, 2990hr 43min 20sec
# second                  Claudio Chiappucci2min 16sec
# third                        Erik Breukink2min 29sec
# winner_origin                                 U.S.A.
# winning_team                                       Z
# age                                               29
# winner_chrono                       90hr 43min 20sec
# winner_timedelta                     3 days 18:43:20
# Name: 76, dtype: object

# %%
df.at[106, "winner_chrono"]
# Out:
# '      87hr 20min 5sec'

# %%
df.at[14, "winner_chrono"] = "221hr 50min 26sec"
df.at[14, "winner_timedelta"] = pd.to_timedelta("221hr 50min 26sec")

# %%
df.at[31, "winner_chrono"] = "148hr 29min 12sec"
df.at[31, "winner_timedelta"] = pd.to_timedelta("148hr 29min 12sec")

# %%
df.at[54, "winner_chrono"] = "133hr 49min 42sec"
df.at[54, "winner_timedelta"] = pd.to_timedelta("133hr 49min 42sec")

# %%
df.at[64, "winner_chrono"] = "112hr 3min 2sec"
df.at[64, "winner_timedelta"] = pd.to_timedelta("112hr 3min 2sec")

# %%
df.at[74, "winner_chrono"] = "84hr 27min 58sec"
df.at[74, "winner_timedelta"] = pd.to_timedelta("84hr 27min 58sec")

# %%
df.at[80, "winner_chrono"] = "103hr 38min 38sec"
df.at[80, "winner_timedelta"] = pd.to_timedelta("103hr 38min 38sec")

# %%
for i in range(97, 107):
    df.at[i, "winner_chrono"] = df.at[i, "winner_chrono"].replace("\t", "")

# %%
df.at[99, "winner_chrono"]
# Out:
# '      83hr 56min 40sec'

# %% [markdown]
# #### Clean up winners name

# %% [markdown]
# The winner's column is still kind of messy. Let's try to clean it up further more now that we have extracted all the values that we cared about.

# %%
metadata["winner"] = []

# %%
def clean_runner(text):
    winner = text.split(",")
    return winner

# %%
for i in range (0, 107):
    a = clean_runner(df.at[i, "winner"])
    metadata["winner"].append(" ".join([a[1][1:], a[0]]))

# %%
df["winner"] = metadata["winner"]

# %%
df.at[14, "winner"] = "Léon Scieur"

# %%
df.at[31, "winner"] = "Gino Bartali"

# %%
df.at[80, "winner"] = "Miguel Induráin"

# %%
df.at[92, "winner"] = "Floyd Landis"

# %%
df.at[93, "winner"] = "Alberto Contador"

# %%
df.at[94, "winner"] = "Carlos Sastre"

# %%
df.at[95, "winner"] = "Alberto Contador"

# %%
df.at[96, "winner"] = "Alberto Contador"

# %%
df.at[97, "winner"] = "Cadel Evans"

# %%
df.at[98, "winner"] = "Bradley Wiggins"

# %%
df.at[99, "winner"] = "Christopher Froome"

# %%
df.at[100, "winner"] = "Vincenzo Nibali"

# %%
for i in range(101, 104):
    df.at[i, "winner"] = "Christopher Froome"

# %%
df.at[104, "winner"] = "Geraint Thomas"

# %%
df.at[105, "winner"] = "Egan Bernal"

# %%
df.at[106, "winner"] = "Tadej Pogacar"

# %% [markdown]
# Now, let's clean the second runner.

# %%
metadata["second"] = []

# %%
def split_with_num(text):
    clean = re.compile(r"\d{1}|@").split(text)
    return clean

# %%
for second in df["second"]:
    a = split_with_num(second)
    metadata["second"].append(a[0])

# %%
df["second"] = metadata["second"]

# %%
df.at[1, "second"] = "Jean-Baptiste Dortignacq"

# %%
df.at[2, "second"] = "Hippolyte Aucouturier"

# %%
df.at[33, "second"] = "Édouard Fachleitner"

# %%
df.at[49, "second"] = "Federico Bahamontes"

# %% [markdown]
# Finally, let's clean the third runner.

# %%
metadata["third"] = []

# %%
for third in df["third"]:
    a = split_with_num(third)
    metadata["third"].append(a[0])

# %%
df["third"] = metadata["third"]

# %% [markdown]
# Let's clean manually some cells.

# %%
df.at[2, "third"] = "Jean-Baptiste Dortignacq"

# %%
df.at[3, "third"] = "Louis Trousselier"

# %%
df.at[7, "third"] = "Gustave Garrigou"

# %%
df.at[9, "third"] = "Gustave Garrigou"

# %%
df.at[16, "third"] = "Romain Bellenger"

# %%
df.at[35, "third"] = "Jacques Marinelli"

# %%
df.at[50, "third"] = "Federico Bahamontes"

# %%
df.at[54, "third"] = "Ferdinand Bracke"

# %%
df.at[56, "third"] = "Gösta Pettersson"

# %%
df.at[57, "third"] = "Lucien Van Impe"

# %%
df.at[61, "third"] = "Lucien Van Impe"

# %%
df.at[63, "third"] = "Lucien Van Impe"

# %%
df.at[72, "third"] = "Urs Zimmermann"

# %%
df.at[73, "third"] = "Jean-François Bernard"

# %%
df.at[82, "third"] = "Richard Virenque"

# %%
df.at[96, "third"] = "Samuel Sánchez"

# %% [markdown]
# ### Convert timedeltas to seconds

# %% [markdown]
# Because we might need to do some calculations, we want to convert each timedeltas to seconds.

# %%
for ind, row in df.iterrows():
    df.at[ind, "winner_seconds"] = pd.to_timedelta(df.at[ind, "winner_chrono"]).total_seconds()
# Out:
# 3 days 22:33:14.000000000
# 4 days 00:05:55.000000000
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 8 days 05:54:00.000000000
# 8 days 08:28:49.000000000
# 9 days 15:07:15.000000000
# 9 days 12:36:13.000000000
# 9 days 05:50:26.000000000
# 9 days 06:08:06.000000000
# 9 days 06:15:30.000000000
# 9 days 10:18:21.000000000
# 9 days 03:10:18.000000000
# 9 days 22:44:25.000000000
# 8 days 06:16:42.000000000
# 8 days 00:48:58.000000000
# 7 days 18:39:16.000000000
# 7 days 04:12:16.000000000
# 7 days 09:10:03.000000000
# 6 days 10:11:49.000000000
# 6 days 03:51:37.000000000
# 6 days 03:13:58.000000000
# 5 days 21:32:00.000000000
# 5 days 22:47:32.000000000
# 5 days 18:58:31.000000000
# 6 days 04:29:12.000000000
# 5 days 12:03:17.000000000
# 6 days 04:11:25.000000000
# 6 days 03:10:36.000000000
# 0 days 03:18:40.000000000
# 6 days 01:36:56.000000000
# 5 days 22:20:14.000000000
# 6 days 07:57:20.000000000
# 5 days 09:23:25.000000000
# 5 days 20:06:05.000000000
# 5 days 10:29:26.000000000
# ...

# %% [markdown]
# ## Export the results

# %% [markdown]
# Now that we have cleaned up our dataset, we want to make sure we export it in a CSV file so we don't have to do all these steps again the next time we want to explore our dataset.

# %%
def clean_winner(text):
    regex = re.compile(r"^ ")
    a = regex.sub(" ", text)
    return a

# %%
metadata["winner"] = []

# %%
for win in df["winner"]:
    a = clean_winner(win)
    metadata["winner"].append(a)

# %%
df.to_csv("data_tdf.csv", sep=";", encoding="utf-8")

# %% [markdown]
# ## Get some additional data

# %% [markdown]
# Because data is poorly formated on every web site that could be used as a source, additionnal data was gathered and added manually. Let's take a look at the new information we have now.

# %%
df_tour = pd.read_csv("data_tour.csv")
df_tour.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df_tour.sample(5)
# Out:
#     id  year           winner              second              third  \
# 35  35  1949     Fausto Coppi        Gino Bartali  Jacques Marinelli
# 57  57  1971      Eddy Merckx      Joop Zoetemelk    Lucien Van Impe
# 90  90  2004  Lance Armstrong      Andreas Klöden         Ivan Basso
# 25  25  1932     André Leducq        Kurt Stoepel  Francesco Camusso
# 78  78  1992  Miguel Induráin  Claudio Chiappucci       Gianni Bugno
#
#    winner_origin winning_team  age       winner_chrono  \
# 35         Italy        Italy   29   149hr 40min 49sec
# 57       Belgium      Molteni   26    96hr 45min 14sec
# 90           USA    US Postal   32     83hr 36min 2sec
# 25        France       France   28  154hr 11min 49sec
# 78         Spain      Banesto   28   100hr 49min 30sec
#
#              winner_timedelta  ...  third_mountain_points      first_sprint  \
# 35  6 days 05:40:49.000000000  ...                   62.0               NaN
# ...

# %% [markdown]
# ## Some EDA

# %% [markdown]
# The first thing we want to look at, is the type of data we have in our different columns.

# %%
df_tour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      107 non-null    int64
#  1   year                    107 non-null    int64
#  2   winner                  107 non-null    object
#  3   second                  107 non-null    object
#  4   third                   107 non-null    object
#  5   winner_origin           107 non-null    object
#  6   winning_team            107 non-null    object
#  7   age                     107 non-null    int64
#  8   winner_chrono           99 non-null     object
#  9   winner_timedelta        99 non-null     object
#  10  winner_seconds          99 non-null     float64
#  11  second_seconds          99 non-null     float64
#  12  third_seconds           99 non-null     float64
#  13  average_speed           107 non-null    float64
# ...

# %% [markdown]
# Now, let's take a look at the shape of our dataset.

# %%
df_tour.shape
# Out:
# (107, 37)

# %% [markdown]
# Let's compute some statistics on this dataset.

# %%
df_tour.describe()
# Out:
#                id         year         age  winner_seconds  second_seconds  \
# count  107.000000   107.000000  107.000000       99.000000       99.000000
# mean    53.000000  1964.392523   27.962617   451461.979798      783.707071
# std     31.032241    34.406767    3.425557   149448.469803     1167.941790
# min      0.000000  1903.000000   20.000000   295512.000000        8.000000
# 25%     26.500000  1933.500000   26.000000   332457.000000      178.500000
# 50%     53.000000  1967.000000   28.000000   412531.000000      362.000000
# 75%     79.500000  1993.500000   30.000000   513233.000000      866.000000
# max    106.000000  2020.000000   36.000000   859465.000000     6501.000000
#
#        third_seconds  average_speed  num_runners  total_length  num_stages  \
# count      99.000000     107.000000   107.000000    107.000000  107.000000
# mean     1406.616162      34.307570   141.504673   4203.196262   20.448598
# ...

# %% [markdown]
# Each piece of information does not necessarily make sense. But we can get some insights looking at those number. For example, we can see that the average age of the winners of the Tour de France throughout its history is 28 years old. The youngest winner of the Tour de France was 20 years old and the oldest was 36 years old.
#
# The average speed is 34 km/h but the fastest average speed is 41.6 km/h which is quite a big gap as the standard deviation illustrates it (5.257).

# %% [markdown]
# ### Exploring the evolution of performances

# %% [markdown]
# #### Average speed and difference between first, second and third places

# %% [markdown]
# The first thing we want to look at is the evolution of performances over time. We can simply plot a graph that illustrates the way the average speed increased over time.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")
plt.figure(figsize=(20, 10))
sns.lineplot(y=df_tour["average_speed"], x=df_tour["year"], data=df_tour)

# %% [markdown]
# We can make some easy calculations to plot the difference between the first, second and third runners of the Tour de France.
#
# If we divide the total length of all the stages in one edition by the total time took to complete them and multiplying that number by 3600 (60 secondes in 1 minute, 60 minutes in 1 hour), we will get the average speed of the runners for each edition.

# %%
winner_ave_speed = df_tour["total_length"] / df_tour["winner_seconds"] * 3600
winner_ave_speed
# Out:
# 0      25.678478
# 1      25.276120
# 2            NaN
# 3            NaN
# 4            NaN
#          ...
# 102    39.616075
# 103    40.996606
# 104    40.234397
# 105    40.578662
# 106    39.892495
# Length: 107, dtype: float64

# %% [markdown]
# Now, as the second and third runners chrono represents how late they are compared to the winner, we want to add that number to the chrono of the winner and then, do the same calculation.

# %%
second_ave_speed = (df_tour["total_length"] / (df_tour["second_seconds"] + df_tour["winner_seconds"])) * 3600
second_ave_speed
# Out:
# 0      25.674330
# 1      25.247803
# 2            NaN
# 3            NaN
# 4            NaN
#          ...
# 102    39.585833
# 103    40.989486
# 104    40.219508
# 105    40.569016
# 106    39.885011
# Length: 107, dtype: float64

# %% [markdown]
# Let's do the same thing with the third runner.

# %%
third_ave_speed = (df_tour["total_length"] / (df_tour["third_seconds"] + df_tour["winner_seconds"])) * 3600
third_ave_speed
# Out:
# 0      25.521106
# 1      24.798507
# 2            NaN
# 3            NaN
# 4            NaN
#          ...
# 102    39.583859
# 103    40.978151
# 104    40.215083
# 105    40.566300
# 106    39.865868
# Length: 107, dtype: float64

# %% [markdown]
# Now, let's build a new DataFrame from those extractions.

# %%
ave_speeds = pd.DataFrame({"year": df_tour["year"], "first": winner_ave_speed, "second": second_ave_speed, "third": third_ave_speed})

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(x="year", y="first", data=ave_speeds, color="b")
sns.lineplot(x="year", y="second", data=ave_speeds, color="r")
sns.lineplot(x="year", y="third", data=ave_speeds, color="g")

# %% [markdown]
# It's quite difficult to see a particular trend when plotting those numbers on the whole serie. Let's take a closer look at the first years of the Tour de France.

# %%
ave_speeds
# Out:
#      year      first     second      third
# 0    1903  25.678478  25.674330  25.521106
# 1    1904  25.276120  25.247803  24.798507
# 2    1905        NaN        NaN        NaN
# 3    1906        NaN        NaN        NaN
# 4    1907        NaN        NaN        NaN
# ..    ...        ...        ...        ...
# 102  2016  39.616075  39.585833  39.583859
# 103  2017  40.996606  40.989486  40.978151
# 104  2018  40.234397  40.219508  40.215083
# 105  2019  40.578662  40.569016  40.566300
# 106  2020  39.892495  39.885011  39.865868
#
# [107 rows x 4 columns]

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(x="year", y="first", data=ave_speeds[0:20], color="b")
sns.lineplot(x="year", y="second", data=ave_speeds[0:20], color="r")
sns.lineplot(x="year", y="third", data=ave_speeds[0:20], color="g")

# %% [markdown]
# Here, we can see that there is quite a huge gap between runners. For example, in 1919, there was a 0.3 km/h difference between the first and the second one.

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(x="year", y="first", data=ave_speeds[96:], color="b")
sns.lineplot(x="year", y="second", data=ave_speeds[96:], color="r")
sns.lineplot(x="year", y="third", data=ave_speeds[96:], color="g")

# %% [markdown]
# If we look at the more recent years, we see that the average speed is really close from the first one and the third one, especially after 2016 : the difference is less than 0.1 km/h.

# %% [markdown]
# Let's plot the difference between the first and the second runner final chrono.

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(y=df_tour["second_seconds"], x=df_tour["year"], data=df_tour)

# %% [markdown]
# We can clearly see that the Tour de France became more and more competitive as time goes by. A big change seems to emerge around the 1960s.

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(y=df_tour["third_seconds"], x=df_tour["year"], data=df_tour)

# %% [markdown]
# Looking at those number does not really make sense if we don't compare them to the evolution of the total distance of the Tour de France.

# %% [markdown]
# #### Total distance

# %% [markdown]
# Let's put the previous number we saw in context. If we look at the total distance of the Tour de France in each edition, we can clearly see that it is decreasing over time.

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(y=df_tour["total_length"], x=df_tour["year"], data=df_tour, color="red")

# %% [markdown]
# Now, let's plot the total distance of the Tour de France for each edition and the chrono of the winner. We can see that the difference between the first and the second of the Tour de France is partly linked to the total length of each edition. However, around the 1960s, the fact that the total length tends to decrease, the difference between the first and the second does not change much in average.

# %%
plt.figure(figsize=(20, 10))
ax = sns.lineplot(data=df_tour["total_length"], color="red", label="Distance")
ax2 = plt.twinx()
ax1 = sns.scatterplot(data=df_tour["second_seconds"], ax=ax2, label="Chrono")
ax.legend(loc=1, fontsize="x-large")
plt.legend(loc=2, fontsize="x-large")
plt.show()

# %% [markdown]
# #### A quick look at nationalities of winners

# %% [markdown]
# Now, let's look at the nationality of the winners. First, the winners of the Tour de France itself.

# %%
df_tour["winner_origin"]
# Out:
# 0             France
# 1             France
# 2             France
# 3             France
# 4             France
#            ...
# 102    Great Britain
# 103    Great Britain
# 104    Great Britain
# 105         Columbia
# 106         Slovenia
# Name: winner_origin, Length: 107, dtype: object

# %% [markdown]
# Let's simply plot those values on a simple histogram.

# %%
plt.figure(figsize=(20, 10))
ax = sns.countplot(x="winner_origin", data=df_tour, order=df_tour["winner_origin"].value_counts().index)
ax.set(xlabel="Winner's country", ylabel="Number of wins")
ax.set_title("Number of wins per country")
# Out:
# Text(0.5, 1.0, 'Number of wins per country')

# %% [markdown]
# Now, we would like to see if some countries are better in the sprint or mountain classification. It is known, for example, that in the current runners generation, Columbians tend to perform better on mountains stages because they can ventilate better than other runners because of their life environment in Columbia (many towns are higher located in places higher than 2000 meters where oxygen is rarer).

# %% [markdown]
# In order to get a better grasp at any specificity that might be linked to mountain or sprint speciality based on runnners origin, we need to think at a way to proceed. Because some runners are so good at climbing or sprinting, they won several times those specific classifications. So, in order to have a more representative idea of the speciality based on origins, we want to drop duplicates before we select the origin of the runners.

# %%
first_mountain_orig = df_tour[["first_mountain", "first_mountain_origin"]].dropna().drop_duplicates("first_mountain")
second_mountain_orig = df_tour[["second_mountain", "second_mountain_origin"]].dropna().drop_duplicates("second_mountain")
third_mountain_orig = df_tour[["third_mountain", "third_mountain_origin"]].dropna().drop_duplicates("third_mountain")

# %%
mountain = first_mountain_orig["first_mountain_origin"].tolist() + \
           second_mountain_orig["second_mountain_origin"].tolist() + \
           third_mountain_orig["third_mountain_origin"].tolist()

# %%
mountain = sorted(mountain, key=mountain.count, reverse=True)

# %%
plt.figure(figsize=(20, 10))
ax = sns.countplot(x=mountain)
ax.set(xlabel= "Runners' origin", ylabel="Number of represent of a country in the top 3 mountain classification")
ax.set_title("Number of different runners that reached top 3 mountain classification on the Tour de France")
# Out:
# Text(0.5, 1.0, 'Number of different runners that reached top 3 mountain classification on the Tour de France')

# %% [markdown]
# We can see that Spain, Belgium and Italy tend to send better runners at climbing than other nations. In the recent years, we can see that Colombia is becoming a great nation of climbers as well.

# %% [markdown]
# Now, let's do the same thing with sprinters.

# %%
first_sprint_orig = df_tour[["first_sprint", "first_sprint_origin"]].dropna().drop_duplicates("first_sprint")
second_sprint_orig = df_tour[["second_sprint", "second_sprint_origin"]].dropna().drop_duplicates("second_sprint")
third_sprint_orig = df_tour[["third_sprint", "third_sprint_origin"]].dropna().drop_duplicates("third_sprint")

# %%
sprint = first_sprint_orig["first_sprint_origin"].tolist() + \
           second_sprint_orig["second_sprint_origin"].tolist() + \
           third_sprint_orig["third_sprint_origin"].tolist()

# %%
sprint = sorted(sprint, key=sprint.count, reverse=True)

# %%
plt.figure(figsize=(20, 10))
ax = sns.countplot(x=sprint)
ax.set(xlabel="Runners' origin", ylabel="Number of represent of a country in the top 3 sprint classification")
ax.set_title("Number of different runners that reached top 3 sprint classification on the Tour de France")
# Out:
# Text(0.5, 1.0, 'Number of different runners that reached top 3 sprint classification on the Tour de France')

# %% [markdown]
# For the case of sprinters, we can see another trend : Belgium runners tend to be better than others (which might be explained by the fact that they might run on "classic races" which usually require less climbing talents but more speed to make a difference in the last kilometer). We can see that Nederlands is also quite better than other countries at sending sprinters on the Tour de France. In the recent years, we see that Australia has better sprinters than other nations.

# %% [markdown]
# ### Merging and comparing data from Tour de France and Giro d'Italia

# %% [markdown]
# #### Length and performances

# %% [markdown]
# Now, we want to compare data from Tour de France and Giro d'Italia. We will proceed in different ways. First, we will graph general data about those two races, then, we will merge the datasets to draw specific comparisons.

# %%
df_giro = pd.read_csv("data_giro.csv")
df_giro.drop(columns=["Unnamed: 0"], inplace=True)

# %%
plt.figure(figsize=(20, 10))
ax = sns.lineplot(x="year", y="total_length", data=df_giro, color="g", label="Giro d'Italia")
ax1 = sns.lineplot(x="year", y="total_length", data=df_tour, color="b", label="Tour de France")
ax.set(xlabel="Years", ylabel="Total length (in km)")
ax.legend(loc=0, fontsize="x-large")
ax1.legend(loc=0, fontsize="x-large")
ax.set_title("Length of all stages on the Giro d'Italia and the Tour de France")
# Out:
# Text(0.5, 1.0, "Length of all stages on the Giro d'Italia and the Tour de France")

# %% [markdown]
# When comparing the Tour de France and the Giro d'Italia, we can see that the total length of both races tend to converge over time, getting closer to 3500 km since 2000.

# %% [markdown]
# Now, we would like to take a look at the difference in runner performances on the Tour de France and the Giro throughout there history.

# %%
plt.figure(figsize=(20, 10))
ax = sns.lineplot(data=df_tour, y="average_speed", x="year", color="b", label="Tour de France")
ax1 = sns.lineplot(data=df_giro, y="average_speed", x="year", color="g", label="Giro d'Italia")
ax.set(xlabel="Years", ylabel="Average speed (in km/h)")
ax.legend(loc=0, fontsize="x-large")
ax1.legend(loc=0, fontsize="x-large")
ax.set_title("Average speed on the Giro d'Italia and the Tour de France")
# Out:
# Text(0.5, 1.0, "Average speed on the Giro d'Italia and the Tour de France")

# %% [markdown]
# If the general trend is an increase of performances on the Giro and the Tour de France, we see that, in the recent years, performances tend to increase faster on the Tour de France then on the Giro. This might be explained by two different factors :
# * The Tour de France is more popular than the Giro, which means that better runners prefer to go on the Tour de France instead of the Giro (because they are too close from on another to participate in both)
# * The Giro might be harder, with more mountain stages than the Tour de France, which would explain the fact that performances tend to be lower on the Giro

# %% [markdown]
# #### Exploring further mountain and sprint classifications

# %% [markdown]
# Now, let's concatenate data on the Tour de France and the Giro d'Italia to explore further our hypothesis about specialities on mountain and sprint classifications depending on runners' origin.

# %%
df = pd.concat([df_tour, df_giro])

# %%
df.sample(5)
# Out:
#     id  year           winner                    second               third  \
# 56  57  1974              NaN  Gianbattista Baronchelli      Felice Gimondi
# 81  82  1999              NaN          Paolo Savoldelli     Gilberto Simoni
# 21  22  1934              NaN         Francesco Camusso  Giovanni Cazzulani
# 67  67  1981  Bernard Hinault           Lucien van Impe        Robert Alban
# 64  65  1982              NaN                Tommy Prim     Silvano Contini
#
#    winner_origin       winning_team  age     winner_chrono  \
# 56           NaN                KAS   29               NaN
# 81           NaN  Vitalicio Seguros   30               NaN
# 21           NaN             Gloria   31               NaN
# 67        France            Renault   26  96hr 19min 38sec
# 64           NaN            Bianchi   27               NaN
#
#              winner_timedelta  ...  third_sprint_origin  first_sprint_points  \
# ...

# %%
first_mountain_orig = df[["first_mountain", "first_mountain_origin"]].dropna().drop_duplicates("first_mountain")
second_mountain_orig = df[["second_mountain", "second_mountain_origin"]].dropna().drop_duplicates("second_mountain")
third_mountain_orig = df[["third_mountain", "third_mountain_origin"]].dropna().drop_duplicates("third_mountain")

# %%
mountain = first_mountain_orig["first_mountain_origin"].tolist() + \
           second_mountain_orig["second_mountain_origin"].tolist() + \
           third_mountain_orig["third_mountain_origin"].tolist()

# %%
mountain = sorted(mountain, key=mountain.count, reverse=True)

# %%
xlabel = dict.fromkeys(mountain)

# %%
plt.figure(figsize=(20, 10))
ax = sns.countplot(x=mountain)
ax.set(xlabel= "Runners' origin", ylabel="Number of represent of a country in the top 3 mountain classification")
ax.set_title("Number of different runners that reached top 3 mountain classification on the Giro or the Tour de France")
ax.set_xticklabels(xlabel, rotation=45)
# Out:
# [Text(0, 0, 'Italie'),
#  Text(0, 0, 'Espagne'),
#  Text(0, 0, 'France'),
#  Text(0, 0, 'Belgique'),
#  Text(0, 0, 'Colombie'),
#  Text(0, 0, 'Suisse'),
#  Text(0, 0, 'Pays-Bas'),
#  Text(0, 0, 'Luxembourg'),
#  Text(0, 0, 'Royaume-Uni'),
#  Text(0, 0, 'Etats-Unis'),
#  Text(0, 0, 'Danemark'),
#  Text(0, 0, 'Slovénie'),
#  Text(0, 0, 'Allemagne'),
#  Text(0, 0, 'Russie'),
#  Text(0, 0, 'Pologne'),
#  Text(0, 0, 'Suède'),
#  Text(0, 0, 'Autriche'),
#  Text(0, 0, 'Australie'),
#  Text(0, 0, 'Biélorussie'),
#  Text(0, 0, 'Portugal'),
#  Text(0, 0, 'Mexique'),
#  Text(0, 0, 'Lettonie'),
#  Text(0, 0, 'Ukraine'),
#  Text(0, 0, 'Costa Rica')]

# %% [markdown]
# When merging data on the Tour de France and the Giro, we can see that our hypothesis is confirmed. We should not pay too much attention at the fact that French and Italian runners are highly represented in this graph. This is especially true for the Giro which, for a long time, tended to be a very national centric race, explaining why Italians are highly represented.
#
# We can still see that Spain, Belgium and Colombia are highly represented in mountain classifications.

# %%
first_sprint_orig = df[["first_sprint", "first_sprint_origin"]].dropna().drop_duplicates("first_sprint")
second_sprint_orig = df[["second_sprint", "second_sprint_origin"]].dropna().drop_duplicates("second_sprint")
third_sprint_orig = df[["third_sprint", "third_sprint_origin"]].dropna().drop_duplicates("third_sprint")

# %%
sprint = first_sprint_orig["first_sprint_origin"].tolist() + \
           second_sprint_orig["second_sprint_origin"].tolist() + \
           third_sprint_orig["third_sprint_origin"].tolist()

# %%
sprint = sorted(sprint, key=sprint.count, reverse=True)

# %%
xlabel = dict.fromkeys(sprint)

# %%
plt.figure(figsize=(20, 10))
ax = sns.countplot(x=sprint)
ax.set_title("Number of different runners that reached top 3 sprint classification on the Giro or the Tour de France")
ax.set(xlabel="Number of represent of a country in the top 3 sprint classification", ylabel="Runners' origin")
ax.set_xticklabels(xlabel, rotation=45)
# Out:
# [Text(0, 0, 'Italie'),
#  Text(0, 0, 'Belgique'),
#  Text(0, 0, 'France'),
#  Text(0, 0, 'Allemagne'),
#  Text(0, 0, 'Pays-Bas'),
#  Text(0, 0, 'Australie'),
#  Text(0, 0, 'Espagne'),
#  Text(0, 0, 'Irlande'),
#  Text(0, 0, 'Suisse'),
#  Text(0, 0, 'Norvège'),
#  Text(0, 0, 'Royaume-Uni'),
#  Text(0, 0, 'Suède'),
#  Text(0, 0, 'Slovaquie'),
#  Text(0, 0, 'Russie'),
#  Text(0, 0, 'Etats-Unis'),
#  Text(0, 0, 'Lettonie'),
#  Text(0, 0, 'Ouzbékistan'),
#  Text(0, 0, 'Colombie'),
#  Text(0, 0, 'Afrique du Sud'),
#  Text(0, 0, 'Danemark'),
#  Text(0, 0, 'Kazakhstan'),
#  Text(0, 0, 'Autriche'),
#  Text(0, 0, 'Canada')]

# %% [markdown]
# When looking at the sprint classification, we can also see the same trend when we merge data from the Tour de France and the Giro : Australia, Nederlands and Belgium are highly represented. Still, the numbers are quite low (10 to 20 different runners in the top 3 sprint classification).

# %% [markdown]
# #### Specialities in the recent years

# %% [markdown]
# Because professionnal biking is getting more and more internationalized since the 2000s onward, we can extract data from the 2000s to look a closer look at the trends we are looking at on the whole history of the Giro and the Tour de France. This might enable to gauge better how France and Italy perform in sprint and mountain classification (the national bias is less present in recent years, though it is still quite significant in Italy).

# %%
df_2000 = df[df["year"] >= 2000]

# %%
first_mountain_orig = df_2000[["first_mountain", "first_mountain_origin"]].dropna().drop_duplicates("first_mountain")
second_mountain_orig = df_2000[["second_mountain", "second_mountain_origin"]].dropna().drop_duplicates("second_mountain")
third_mountain_orig = df_2000[["third_mountain", "third_mountain_origin"]].dropna().drop_duplicates("third_mountain")

# %%
mountain = first_mountain_orig["first_mountain_origin"].tolist() + \
           second_mountain_orig["second_mountain_origin"].tolist() + \
           third_mountain_orig["third_mountain_origin"].tolist()

# %%
mountain = sorted(mountain, key=mountain.count, reverse=True)

# %%
xlabel = dict.fromkeys(mountain)

# %%
plt.figure(figsize=(20, 10))
ax = sns.countplot(x=mountain)
ax.set(xlabel= "Runners' origin", ylabel="Number of represent of a country in the top 3 mountain classification")
ax.set_title("Number of different runners that reached top 3 mountain classification on the Giro or the Tour de France since 2000")
ax.set_xticklabels(xlabel, rotation=45)
# Out:
# [Text(0, 0, 'Italie'),
#  Text(0, 0, 'Colombie'),
#  Text(0, 0, 'Espagne'),
#  Text(0, 0, 'France'),
#  Text(0, 0, 'Belgique'),
#  Text(0, 0, 'Danemark'),
#  Text(0, 0, 'Royaume-Uni'),
#  Text(0, 0, 'Slovénie'),
#  Text(0, 0, 'Etats-Unis'),
#  Text(0, 0, 'Luxembourg'),
#  Text(0, 0, 'Pologne'),
#  Text(0, 0, 'Allemagne'),
#  Text(0, 0, 'Suisse'),
#  Text(0, 0, 'Russie'),
#  Text(0, 0, 'Autriche'),
#  Text(0, 0, 'Australie'),
#  Text(0, 0, 'Suède'),
#  Text(0, 0, 'Biélorussie'),
#  Text(0, 0, 'Ukraine'),
#  Text(0, 0, 'Costa Rica'),
#  Text(0, 0, 'Pays-Bas')]

# %% [markdown]
# This confirms our hypothesis concerning Colombia. It might also show that French runners might actually be quite good at mountain classification. The same thing seems true with Italian runners, however, we can still think that there is a national bias linked to this race which could probably be explained in on way or another.

# %%
first_sprint_orig = df_2000[["first_sprint", "first_sprint_origin"]].dropna().drop_duplicates("first_sprint")
second_sprint_orig = df_2000[["second_sprint", "second_sprint_origin"]].dropna().drop_duplicates("second_sprint")
third_sprint_orig = df_2000[["third_sprint", "third_sprint_origin"]].dropna().drop_duplicates("third_sprint")

# %%
sprint = first_sprint_orig["first_sprint_origin"].tolist() + \
           second_sprint_orig["second_sprint_origin"].tolist() + \
           third_sprint_orig["third_sprint_origin"].tolist()

# %%
sprint = sorted(sprint, key=sprint.count, reverse=True)

# %%
xlabel = dict.fromkeys(sprint)

# %%
plt.figure(figsize=(20, 10))
ax = sns.countplot(x=sprint)
ax.set_title("Number of different runners that reached top 3 sprint classification on the Giro or the Tour de France")
ax.set(xlabel="Number of represent of a country in the top 3 sprint classification", ylabel="Runners' origin")
ax.set_xticklabels(xlabel, rotation=45)
# Out:
# [Text(0, 0, 'Italie'),
#  Text(0, 0, 'Australie'),
#  Text(0, 0, 'Allemagne'),
#  Text(0, 0, 'Espagne'),
#  Text(0, 0, 'Norvège'),
#  Text(0, 0, 'France'),
#  Text(0, 0, 'Belgique'),
#  Text(0, 0, 'Irlande'),
#  Text(0, 0, 'Royaume-Uni'),
#  Text(0, 0, 'Slovaquie'),
#  Text(0, 0, 'Russie'),
#  Text(0, 0, 'Colombie'),
#  Text(0, 0, 'Afrique du Sud'),
#  Text(0, 0, 'Kazakhstan'),
#  Text(0, 0, 'Lettonie'),
#  Text(0, 0, 'République Tchèque'),
#  Text(0, 0, 'Canada')]

# %% [markdown]
# This graph confirms the national bias for Italy that is still very present after 2000. However, we can see that Australia is well representend in sprint classification, as well as Germany. However, Belgium is quite absent contrary to the numbers we get when we study the whole history of the Giro and the Tour de France.
